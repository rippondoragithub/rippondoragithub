# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas import ExcelWriter
from pandas import ExcelFile

# %%
df = pd.read_excel('National_Fossil_Carbon_Emissions_2022v1.0.xlsx', sheet_name = 'Territorial Emissions', skiprows = 11, index_col = 0)

# %%
df.head()
# Out:
#       Afghanistan  Albania  Algeria  Andorra  Angola  Anguilla  \
# 1850          NaN      NaN      NaN      NaN     NaN       NaN
# 1851          NaN      NaN      NaN      NaN     NaN       NaN
# 1852          NaN      NaN      NaN      NaN     NaN       NaN
# 1853          NaN      NaN      NaN      NaN     NaN       NaN
# 1854          NaN      NaN      NaN      NaN     NaN       NaN
#
#       Antigua and Barbuda  Argentina   Armenia  Aruba  ...      Asia  \
# 1850                  NaN        NaN  0.000069    0.0  ...  0.004014
# 1851                  NaN        NaN  0.000000    0.0  ...  0.000000
# 1852                  NaN        NaN  0.000000    0.0  ...  0.000000
# 1853                  NaN        NaN  0.000000    0.0  ...  0.000000
# 1854                  NaN        NaN  0.000000    0.0  ...  0.000000
#
#       Central America     Europe  Middle East  North America  Oceania  \
# 1850              0.0  48.315986          0.0          5.418      0.0
# 1851              0.0  47.517000          0.0          6.742      0.0
# 1852              0.0  49.311000          0.0          7.335      0.0
# 1853              0.0  51.022000          0.0          8.260      0.0
# 1854              0.0  60.550000          0.0          9.084      0.0
#
#       South America  Bunkers  Statistical Difference   World
# 1850            0.0      0.0            0.000000e+00  53.738
# 1851            0.0      0.0            0.000000e+00  54.259
# 1852            0.0      0.0           -7.105427e-15  56.646
# 1853            0.0      0.0           -7.105427e-15  59.282
# 1854            0.0      0.0            0.000000e+00  69.634
#
# [5 rows x 235 columns]

# %%
#1 MtC = 1 million tonne of carbon = 3.664 million tonnes of carbon dioxide.

# %%
df_1994 = df.loc[1994:]

# %%
df_1994.head()
# Out:
#       Afghanistan   Albania    Algeria  Andorra    Angola  Anguilla  \
# 1994     0.396787  0.525056  23.511866    0.111  1.054727     0.018
# 1995     0.386825  0.570160  25.922876    0.116  2.988239     0.018
# 1996     0.373937  0.550630  26.415469    0.124  2.844976     0.019
# 1997     0.355937  0.421127  23.745826    0.127  2.005367     0.019
# 1998     0.348937  0.478905  29.099621    0.134  1.983739     0.021
#
#       Antigua and Barbuda  Argentina   Armenia  Aruba  ...         Asia  \
# 1994                0.059  33.359444  0.740541  0.180  ...  1849.427047
# 1995                0.061  34.870322  0.937003  0.193  ...  1948.703974
# 1996                0.065  36.780041  0.708362  0.198  ...  2034.534390
# 1997                0.070  37.565902  0.892259  0.207  ...  2071.206681
# 1998                0.074  38.060015  0.927187  0.220  ...  1986.083944
#
#       Central America       Europe  Middle East  North America     Oceania  \
# 1994        27.084104  1759.595887   312.916815    1691.156837   88.925329
# 1995        28.971749  1753.874389   301.255416    1706.164197   92.082196
# 1996        30.686071  1766.709153   305.857161    1765.931787   94.371051
# 1997        32.253807  1710.775413   300.672668    1796.674292   97.109765
# 1998        31.949023  1703.836400   312.603405    1816.535919  100.484972
#
#       South America     Bunkers  Statistical Difference        World
# 1994     183.313322  160.186938            4.547474e-13  6268.967892
# 1995     191.538160  169.232529            6.252776e-13  6402.487190
# 1996     198.720663  183.118145            1.250555e-12  6593.717869
# 1997     209.724795  192.604441           -1.080025e-12  6632.801045
# 1998     224.076930  204.184828           -1.051603e-12  6608.422629
#
# [5 rows x 235 columns]

# %%
df_sum = df_1994.sum()

# %%
df_sum.nlargest(30)
# Out:
# World             234749.471139
# Non-OECD          128026.364860
# Non KP Annex B    122831.811384
# KP Annex B        104597.109406
# OECD               99402.555930
# Asia               96075.453287
# China              53954.603856
# North America      50498.895845
# Europe             46134.563418
# USA                42897.716243
# EU27               26021.156755
# Middle East        14480.678218
# Russia             12225.618865
# India              12050.174601
# Japan               9381.934981
# Africa              8497.982798
# South America       7354.790347
# Bunkers             7320.550349
# Germany             6431.151403
# Canada              4249.721668
# South Korea         4067.386196
# Iran                3862.950628
# United Kingdom      3826.759027
# Saudi Arabia        3430.855172
# Mexico              3346.452077
# South Africa        3246.903358
# Italy               3242.907759
# Oceania             3197.500586
# Indonesia           3125.203789
# Brazil              3090.709733
# dtype: float64

# %%
countries = ['China', 'USA', 'Russia', 'India', 'Japan', 'Germany', 'Canada', 'South Korea', 'Iran', 'United Kingdom']
top_10 = df_sum[['China', 'USA', 'Russia', 'India', 'Japan', 'Germany', 'Canada', 'South Korea', 'Iran', 'United Kingdom']]

# %%
plt.figure(figsize = (10,8))
plt.bar(countries, top_10, color = 'green', width = 0.5)
plt.xlabel('Country')
plt.ylabel('Millions of tonnes of carbon')
plt.title('Top 10 Countries Carbon Emissions since 1994')
# Out:
# Text(0.5, 1.0, 'Top 10 Countries Carbon Emissions since 1994')

# %%
top_10['Population'] = [1425671352, 339996563, 144444359, 1428627663, 123294513, 83294633, 38781291, 51784059, 89172767, 67736802]

# %%
top_10
# Out:
#                            0  Population
# China           53954.603856  1425671352
# USA             42897.716243   339996563
# Russia          12225.618865   144444359
# India           12050.174601  1428627663
# Japan            9381.934981   123294513
# Germany          6431.151403    83294633
# Canada           4249.721668    38781291
# South Korea      4067.386196    51784059
# Iran             3862.950628    89172767
# United Kingdom   3826.759027    67736802

# %%
top_10.rename(columns = {0 : 'Total Emissions Since 1994'}, inplace = True)

# %%
top_10['Emissions Per Capita Since 1994'] = top_10['Total Emissions Since 1994'] / top_10['Population']

# %%
top_10
# Out:
#                 Total Emissions Since 1994  Population  \
# China                         53954.603856  1425671352
# USA                           42897.716243   339996563
# Russia                        12225.618865   144444359
# India                         12050.174601  1428627663
# Japan                          9381.934981   123294513
# Germany                        6431.151403    83294633
# Canada                         4249.721668    38781291
# South Korea                    4067.386196    51784059
# Iran                           3862.950628    89172767
# United Kingdom                 3826.759027    67736802
#
#                 Emissions Per Capita Since 1994
# China                                  0.000038
# USA                                    0.000126
# Russia                                 0.000085
# India                                  0.000008
# Japan                                  0.000076
# Germany                                0.000077
# Canada                                 0.000110
# South Korea                            0.000079
# Iran                                   0.000043
# United Kingdom                         0.000056

# %%
top_10.sort_values(by = 'Emissions Per Capita Since 1994', ascending = False)
# Out:
#                 Total Emissions Since 1994  Population  \
# USA                           42897.716243   339996563
# Canada                         4249.721668    38781291
# Russia                        12225.618865   144444359
# South Korea                    4067.386196    51784059
# Germany                        6431.151403    83294633
# Japan                          9381.934981   123294513
# United Kingdom                 3826.759027    67736802
# Iran                           3862.950628    89172767
# China                         53954.603856  1425671352
# India                         12050.174601  1428627663
#
#                 Emissions Per Capita Since 1994
# USA                                    0.000126
# Canada                                 0.000110
# Russia                                 0.000085
# South Korea                            0.000079
# Germany                                0.000077
# Japan                                  0.000076
# United Kingdom                         0.000056
# Iran                                   0.000043
# China                                  0.000038
# India                                  0.000008

# %%
countries_per_capita = ['USA', 'China', 'Russia', 'South Korea', 'Germany', 'Japan', 'United Kingdom', 'Iran', 'China', 'India']
top_10_percapita = top_10['Emissions Per Capita Since 1994'].nlargest(10)

# %%
plt.figure(figsize = (10,8))
plt.bar(countries_per_capita, top_10_percapita, color = 'blue', width = 0.5)
plt.xlabel('Country')
plt.ylabel('Total Emissions Since 1994 Per Capita')
plt.title('Top 10 Country\'s Carbon Emissions by per capita')
# Out:
# Text(0.5, 1.0, "Top 10 Country's Carbon Emissions by per capita")
